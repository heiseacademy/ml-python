# %% [markdown]
# # Einfaches Machine Learning mit `scikit-learn`

# %% [markdown]
# `scikit-learn` ist das Standard-Tool für Machine Learning in Python. Fast alle *klassischen ML-Verfahren* werden durch `scikit-learn` unterstützt.
#
# `scikit-learn` verfügt (im Gegensatz zu vielen anderen Open-Source-Paketen) über eine fantatische Dokumentation, die du dir unter https://scikit-learn.org/stable/ unbedingt anschauen solltest.
#
# Sehr praktisch ist auch, dass `scikit-learn` bereits Datensets mitbringt, mit denen man die Funktionalität ausprobieren kann.

# %% [markdown]
# ## Supervised Learning

# %% [markdown]
# Als ganz einfaches Beispiel nutzen wir hier ein Datenset, das aus 20 Newsgroups besteht. Es ist zwar schon ziemlich alt, aber die Sprache hat sich nicht sehr geändert. Das Datenset lässt sich ganz leicht laden:

# %%
from sklearn.datasets import fetch_20newsgroups
newsgroups_train = fetch_20newsgroups(subset='train')

# %% [markdown]
# Die Daten findest du in dem Schlüssel `data` des zurückgelieferten `dict`.

# %%
len(newsgroups_train['data'])
# Out:
# 11314

# %%
newsgroups_train['data'][0]
# Out:
# "From: lerxst@wam.umd.edu (where's my thing)\nSubject: WHAT car is this!?\nNntp-Posting-Host: rac3.wam.umd.edu\nOrganization: University of Maryland, College Park\nLines: 15\n\n I was wondering if anyone out there could enlighten me on this car I saw\nthe other day. It was a 2-door sports car, looked to be from the late 60s/\nearly 70s. It was called a Bricklin. The doors were really small. In addition,\nthe front bumper was separate from the rest of the body. This is \nall I know. If anyone can tellme a model name, engine specs, years\nof production, where this car is made, history, or whatever info you\nhave on this funky looking car, please e-mail.\n\nThanks,\n- IL\n   ---- brought to you by your neighborhood Lerxst ----\n\n\n\n\n"

# %%
newsgroups_train['target'][0]
# Out:
# 7

# %% [markdown]
# Und jetzt kannst du fast schon mit dem Machine Learning beginnen. Die Daten müssen nur noch *vektorisiert* werden. Was dabei genau passiert, schauen wir uns später noch an:

# %%
from sklearn.feature_extraction.text import TfidfVectorizer
vectorizer = TfidfVectorizer()
vectors = vectorizer.fit_transform(newsgroups_train.data)

# %% [markdown]
# Sobald du die Vektoren zur Verfügung hast, kannst du einen Klassifikator trainieren, hier eine sog. *Support Vector Machine*. Der Klassifikator soll lernen, aufgrund eines Newsgroups-Posting die korrekte Kategorie (in diesem Fall die Newsgroup, in der gepostet wurde) zu erraten. Ein solches Problem heißt *Klassifikationsproblem*.

# %%
vectors.shape
# Out:
# (11314, 130107)

# %%
vectors.data.nbytesytes
# Out:
# 14300520

# %%
from sklearn.linear_model import SGDClassifier
clf = SGDClassifier(loss='hinge', max_iter=1000, tol=1e-3, 
                    random_state=42)
clf.fit(vectors, newsgroups_train.target)
# Out:
# SGDClassifier(random_state=42)

# %% [markdown]
# Das ging **schnell**. Immerhin waren es über 11.000 Texte, aus denen das Modell die Kategoriezuordnung gelernt hat.

# %% [markdown]
# Anhand einer unabhängigen Datenmenge kannst die Ergebnisse verfizieren:

# %%
from sklearn import metrics
newsgroups_test = fetch_20newsgroups(subset='test')
vectors_test = vectorizer.transform(newsgroups_test.data)
pred = clf.predict(vectors_test)
metrics.f1_score(newsgroups_test.target, pred, average='macro')
# Out:
# 0.8445789829167119

# %% [markdown]
# Auch das geh sehr schnell und mit über 84% *F-Score* ziemlich genau. Wenn du dir anschauen möchtest, wo Fehler passiert sind, hilft die sog. *Confusion Matrix*, die in der Diagonale die richtigen Ergebnisse zeigt:

# %%
import pandas as pd
pd.DataFrame(metrics.confusion_matrix(newsgroups_test.target, pred), 
             columns=newsgroups_train.target_names, index=newsgroups_train.target_names)
# Out:
#                           alt.atheism  comp.graphics  comp.os.ms-windows.misc  \
# alt.atheism                       247              1                        0
# comp.graphics                       1            304                       16
# comp.os.ms-windows.misc             0             17                      289
# comp.sys.ibm.pc.hardware            0              9                       25
# comp.sys.mac.hardware               0              5                        5
# comp.windows.x                      1             33                       39
# misc.forsale                        0              1                        1
# rec.autos                           0              1                        0
# rec.motorcycles                     0              0                        0
# rec.sport.baseball                  0              0                        1
# rec.sport.hockey                    0              0                        0
# sci.crypt                           1              1                        1
# sci.electronics                     0              3                        4
# sci.med                             3              5                        3
# sci.space                           0              6                        0
# soc.religion.christian              4              0                        2
# talk.politics.guns                  1              0                        0
# talk.politics.mideast               6              2                        0
# talk.politics.misc                  2              1                        0
# talk.religion.misc                 36              1                        1
#
#                           comp.sys.ibm.pc.hardware  comp.sys.mac.hardware  \
# alt.atheism                                      2                      0
# comp.graphics                                    7                      5
# comp.os.ms-windows.misc                         36                     10
# comp.sys.ibm.pc.hardware                       294                     27
# comp.sys.mac.hardware                           17                    333
# comp.windows.x                                   3                      3
# misc.forsale                                     9                      5
# rec.autos                                        5                      2
# rec.motorcycles                                  1                      0
# rec.sport.baseball                               0                      1
# rec.sport.hockey                                 1                      4
# sci.crypt                                        0                      1
# sci.electronics                                 21                      9
# sci.med                                          2                      3
# sci.space                                        1                      1
# soc.religion.christian                           1                      0
# talk.politics.guns                               1                      1
# talk.politics.mideast                            0                      0
# talk.politics.misc                               0                      1
# talk.religion.misc                               1                      0
#
#                           comp.windows.x  misc.forsale  rec.autos  \
# alt.atheism                            2             1          0
# comp.graphics                         21             3          2
# comp.os.ms-windows.misc               11             4          1
# comp.sys.ibm.pc.hardware               1            14          3
# comp.sys.mac.hardware                  0             9          0
# comp.windows.x                       299             3          1
# misc.forsale                           0           356          5
# rec.autos                              0            10        358
# rec.motorcycles                        0             4          9
# rec.sport.baseball                     0             4          0
# rec.sport.hockey                       0             1          0
# sci.crypt                              2             3          2
# sci.electronics                        2             6          5
# sci.med                                2             2          0
# sci.space                              0             1          0
# soc.religion.christian                 0             0          0
# talk.politics.guns                     0             3          0
# talk.politics.mideast                  2             0          1
# talk.politics.misc                     0             1          1
# talk.religion.misc                     0             2          0
#
#                           rec.motorcycles  rec.sport.baseball  \
# alt.atheism                             1                   1
# comp.graphics                           1                   2
# comp.os.ms-windows.misc                 0                   5
# comp.sys.ibm.pc.hardware                1                   1
# comp.sys.mac.hardware                   0                   2
# comp.windows.x                          2                   1
# misc.forsale                            1                   2
# rec.autos                               6                   2
# rec.motorcycles                       380                   1
# rec.sport.baseball                      0                 378
# rec.sport.hockey                        0                   3
# sci.crypt                               1                   4
# sci.electronics                         4                   2
# sci.med                                 1                   3
# sci.space                               0                   0
# soc.religion.christian                  1                   1
# talk.politics.guns                      1                   2
# talk.politics.mideast                   1                   3
# talk.politics.misc                      0                   0
# talk.religion.misc                      0                   2
#
#                           rec.sport.hockey  sci.crypt  sci.electronics  \
# alt.atheism                              0          3                1
# comp.graphics                            1          5               10
# comp.os.ms-windows.misc                  0          3                1
# comp.sys.ibm.pc.hardware                 0          1               14
# comp.sys.mac.hardware                    1          1                7
# comp.windows.x                           0          2                1
# misc.forsale                             1          1                5
# rec.autos                                0          0                7
# rec.motorcycles                          0          0                0
# rec.sport.baseball                      12          0                0
# rec.sport.hockey                       389          1                0
# sci.crypt                                0        374                2
# sci.electronics                          1          8              310
# sci.med                                  1          1                6
# sci.space                                1          1                4
# soc.religion.christian                   0          0                1
# talk.politics.guns                       0          3                0
# talk.politics.mideast                    0          1                0
# talk.politics.misc                       1          3                0
# talk.religion.misc                       0          0                0
#
#                           sci.med  sci.space  soc.religion.christian  \
# alt.atheism                     6          7                      25
# comp.graphics                   0          5                       1
# comp.os.ms-windows.misc         2          5                       2
# comp.sys.ibm.pc.hardware        0          1                       0
# comp.sys.mac.hardware           1          0                       0
# comp.windows.x                  2          3                       1
# misc.forsale                    2          0                       0
# rec.autos                       1          0                       0
# rec.motorcycles                 2          0                       1
# rec.sport.baseball              0          0                       0
# rec.sport.hockey                0          0                       0
# sci.crypt                       0          0                       0
# sci.electronics                 7          4                       1
# sci.med                       349          1                       4
# sci.space                       5        372                       1
# soc.religion.christian          2          4                     372
# talk.politics.guns              3          1                       0
# talk.politics.mideast           0          1                       4
# talk.politics.misc              3          5                       4
# talk.religion.misc              3          5                      33
#
#                           talk.politics.guns  talk.politics.mideast  \
# alt.atheism                                0                      3
# comp.graphics                              0                      2
# comp.os.ms-windows.misc                    1                      1
# comp.sys.ibm.pc.hardware                   0                      0
# comp.sys.mac.hardware                      2                      0
# comp.windows.x                             1                      0
# misc.forsale                               0                      0
# rec.autos                                  2                      0
# rec.motorcycles                            0                      0
# rec.sport.baseball                         0                      1
# rec.sport.hockey                           0                      0
# sci.crypt                                  3                      0
# sci.electronics                            3                      1
# sci.med                                    1                      3
# sci.space                                  1                      0
# soc.religion.christian                     0                      0
# talk.politics.guns                       332                      2
# talk.politics.mideast                      1                    346
# talk.politics.misc                        90                      3
# talk.religion.misc                        12                      1
#
#                           talk.politics.misc  talk.religion.misc
# alt.atheism                                1                  18
# comp.graphics                              0                   3
# comp.os.ms-windows.misc                    1                   5
# comp.sys.ibm.pc.hardware                   0                   1
# comp.sys.mac.hardware                      2                   0
# comp.windows.x                             0                   0
# misc.forsale                               0                   1
# rec.autos                                  2                   0
# rec.motorcycles                            0                   0
# rec.sport.baseball                         0                   0
# rec.sport.hockey                           0                   0
# sci.crypt                                  1                   0
# sci.electronics                            1                   1
# sci.med                                    3                   3
# sci.space                                  0                   0
# soc.religion.christian                     0                  10
# talk.politics.guns                         8                   6
# talk.politics.mideast                      8                   0
# talk.politics.misc                       189                   6
# talk.religion.misc                         6                 148

# %% [markdown]
# Die Verwechslungen von `alt.atheism` mit `talk.religion.misc` und `soc.religion.christian` kann man in Nicht-Diagonal-Elementen der Confusion Matrix gut erkennen. Die könnten einem Menschen auch passieren, genau wie `comp.os.ms-windows.misc` mit `comp.sys.ibm.pc.hardware` und `comp.windows.x`

# %% [markdown]
# ## Unsupervised Learning

# %% [markdown]
# `scikit-learn` kann nebem *überwachtem Lernen* auch viel Funktionen zum *unüberwachten Lernen* vorweisen. Unüberwachtes Lernen kannst du dazu nutzen, die organische Struktur eines Textkorpus zu explorieren:

# %%
from sklearn.decomposition import NMF
nmf = NMF(n_components=5)
nmf.fit(vectors)
# Out:
# NMF(n_components=5)

# %%
features = vectorizer.get_feature_names()
topics = []
for topic, word_vector in enumerate(nmf.components_):
    total = word_vector.sum()
    largest = word_vector.argsort()[::-1] # invert sort order
    
    topics.append([f" {features[largest[i]]}" for i in range(5)])
pd.DataFrame(topics, columns=[f"Wort {i}" for i in range(5)], index=[f"Topic {i}" for i in range(5)])
# Out:
# /home/cwinkler/.venv/jupyter/lib/python3.8/site-packages/sklearn/utils/deprecation.py:87: FutureWarning: Function get_feature_names is deprecated; get_feature_names is deprecated in 1.0 and will be removed in 1.2. Please use get_feature_names_out instead.
#   warnings.warn(msg, category=FutureWarning)
#         Wort 0 Wort 1   Wort 2  Wort 3 Wort 4
# Topic 0    the     of      and      to     in
# Topic 1    edu    for       to     com     it
# Topic 2    you     to     that      is     it
# Topic 3     he    the      was      in    his
# Topic 4   pitt    geb   gordon   banks     cs

# %% [markdown]
# Hier siehst du, dass wir noch mehr Arbeit in die Vorbereitung der Daten stecken müssen. Die wichtigsten Worte der Topics sind fast alle ziemlich bedeutungslos (sog. *Stoppworte*). Lösungen dafür schauen wir uns im Laufe des Kurses an.

# %% [markdown]
# ## `scikit-learn` kann noch viel mehr

# %% [markdown]
# Du hast bisher nur an der Oberfläche von `scikit-learn` gekratzt. `scikit-learn` bietet noch viel mehr Algorithmen,
# Methoden und Konzepte, die wir uns in späteren Lektionen genau ansehen werden.
